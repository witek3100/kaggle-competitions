# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import re
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.neighbors import KNeighborsRegressor
import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
train = pd.read_csv('/kaggle/input/walmart-sales-prediction-pune-march-2023/train.csv')
train
# Out:
#      Year  Month ProductCategory  Sales(In ThousandDollars)
# 0    2009      1   WomenClothing                     1755.0
# 1    2009      1     MenClothing                      524.0
# 2    2009      1   OtherClothing                      936.0
# 3    2009      2   WomenClothing                     1729.0
# 4    2009      2     MenClothing                      496.0
# ..    ...    ...             ...                        ...
# 175  2013     11     MenClothing                      798.0
# 176  2013     11   OtherClothing                     1209.0
# 177  2013     12   WomenClothing                     4865.0
# 178  2013     12     MenClothing                     1085.0
# 179  2013     12   OtherClothing                     1566.0
#
# [180 rows x 4 columns]

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# ## Macro economic data

# %%
me_df = pd.read_excel('/kaggle/input/walmart-sales-prediction-pune-march-2023/macro_economic.xlsx', 'Sheet1')
me_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 18 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Year-Month                                                         96 non-null     object
#  1   Monthly Nominal GDP Index (inMillion$)                             96 non-null     float64
#  2   Monthly Real GDP Index (inMillion$)                                96 non-null     float64
#  3   CPI                                                                96 non-null     float64
#  4   PartyInPower                                                       96 non-null     object
#  5   unemployment rate                                                  96 non-null     float64
#  6   CommercialBankInterestRateonCreditCardPlans                        96 non-null     float64
#  7   Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  96 non-null     float64
#  8   Earnings or wages  in dollars per hour                             96 non-null     float64
#  9   AdvertisingExpenses (in Thousand Dollars)                          96 non-null     object
#  10  Cotton Monthly Price - US cents per Pound(lbs)                     96 non-null     float64
#  11  Change(in%)                                                        96 non-null     float64
#  12  Average upland planted(million acres)                              96 non-null     float64
#  13  Average upland harvested(million acres)                            96 non-null     float64
#  14  yieldperharvested acre                                             96 non-null     int64
#  15  Production (in  480-lb netweright in million bales)                96 non-null     float64
#  16  Mill use  (in  480-lb netweright in million bales)                 96 non-null     float64
#  17  Exports                                                            96 non-null     float64
# dtypes: float64(14), int64(1), object(3)
# memory usage: 13.6+ KB

# %%
me_df.set_index('Year-Month', inplace=True)
me_df
# Out:
#             Monthly Nominal GDP Index (inMillion$)  \
# Year-Month
# 2009 - Jan                            14421.752895
# 2009 - Feb                            14389.200466
# 2009 - Mar                            14340.701639
# 2009 - Apr                            14326.815525
# 2009 - May                            14345.904809
# ...                                            ...
# 2016 - Aug                            18741.599947
# 2016 - Sep                            18840.309646
# 2016 - Oct                            18740.780023
# 2016 - Nov                            18960.461568
# 2016 - Dec                            19015.393408
#
#             Monthly Real GDP Index (inMillion$)      CPI PartyInPower  \
# Year-Month
# 2009 - Jan                         14407.053343  233.402    Democrats
# 2009 - Feb                         14366.176571  234.663    Democrats
# 2009 - Mar                         14351.786822  235.067    Democrats
# 2009 - Apr                         14351.601731  235.582    Democrats
# 2009 - May                         14368.123959  235.975    Democrats
# ...                                         ...      ...          ...
# 2016 - Aug                         16797.206610  264.160    Democrats
# 2016 - Sep                         16852.562745  264.602    Democrats
# 2016 - Oct                         16725.460098  264.738    Democrats
# 2016 - Nov                         16910.896330  265.203    Democrats
# 2016 - Dec                         16918.050624  265.421    Democrats
#
#             unemployment rate  CommercialBankInterestRateonCreditCardPlans  \
# Year-Month
# 2009 - Jan                7.8                                        12.03
# 2009 - Feb                8.3                                        12.97
# 2009 - Mar                8.7                                        12.97
# 2009 - Apr                9.0                                        12.97
# 2009 - May                9.4                                        13.32
# ...                       ...                                          ...
# 2016 - Aug                4.9                                        12.51
# 2016 - Sep                4.9                                        12.51
# 2016 - Oct                4.8                                        12.51
# 2016 - Nov                4.6                                        12.41
# 2016 - Dec                4.7                                        12.41
#
#             Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# Year-Month
# 2009 - Jan                                              11.44
# 2009 - Feb                                              11.05
# 2009 - Mar                                              11.05
# 2009 - Apr                                              11.05
# 2009 - May                                              11.25
# ...                                                       ...
# 2016 - Aug                                               9.64
# 2016 - Sep                                               9.64
# 2016 - Oct                                               9.64
# 2016 - Nov                                               9.45
# 2016 - Dec                                               9.45
#
#             Earnings or wages  in dollars per hour  \
# Year-Month
# 2009 - Jan                                   22.05
# 2009 - Feb                                   22.22
# 2009 - Mar                                   22.22
# 2009 - Apr                                   22.13
# 2009 - May                                   22.04
# ...                                            ...
# 2016 - Aug                                   25.52
# 2016 - Sep                                   25.74
# 2016 - Oct                                   26.04
# 2016 - Nov                                   25.87
# 2016 - Dec                                   25.90
#
#            AdvertisingExpenses (in Thousand Dollars)  \
# Year-Month
# 2009 - Jan                                       137
# 2009 - Feb                                       200
# 2009 - Mar                                         ?
# 2009 - Apr                                       214
# 2009 - May                                         ?
# ...                                              ...
# 2016 - Aug                                         ?
# 2016 - Sep                                         ?
# 2016 - Oct                                         ?
# 2016 - Nov                                         ?
# 2016 - Dec                                         ?
#
#             Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  \
# Year-Month
# 2009 - Jan                                           57.70         4.02
# 2009 - Feb                                           55.21        -4.32
# 2009 - Mar                                           51.50        -6.72
# 2009 - Apr                                           56.78        10.25
# 2009 - May                                           61.95         9.11
# ...                                                    ...          ...
# 2016 - Aug                                           80.26        -0.99
# 2016 - Sep                                           77.86        -2.99
# 2016 - Oct                                           78.52         0.85
# 2016 - Nov                                           78.92         0.51
# 2016 - Dec                                           79.50         0.73
#
#             Average upland planted(million acres)  \
# Year-Month
# 2009 - Jan                                  9.296
# 2009 - Feb                                  9.296
# 2009 - Mar                                  9.296
# 2009 - Apr                                  9.296
# 2009 - May                                  9.297
# ...                                           ...
# 2016 - Aug                                  9.824
# 2016 - Sep                                  9.950
# 2016 - Oct                                  9.950
# 2016 - Nov                                  9.950
# 2016 - Dec                                  9.950
#
#             Average upland harvested(million acres)  yieldperharvested acre  \
# Year-Month
# 2009 - Jan                                    7.559                     799
# 2009 - Feb                                    7.559                     799
# 2009 - Mar                                    7.559                     799
# 2009 - Apr                                    7.559                     787
# 2009 - May                                    7.400                     803
# ...                                             ...                     ...
# 2016 - Aug                                    9.340                     787
# 2016 - Sep                                    9.464                     790
# 2016 - Oct                                    9.464                     785
# 2016 - Nov                                    9.464                     791
# 2016 - Dec                                    9.464                     810
#
#             Production (in  480-lb netweright in million bales)  \
# Year-Month
# 2009 - Jan                                             12.589
# 2009 - Feb                                             12.589
# 2009 - Mar                                             12.589
# 2009 - Apr                                             12.400
# 2009 - May                                             12.384
# ...                                                       ...
# 2016 - Aug                                             15.314
# 2016 - Sep                                             15.580
# 2016 - Oct                                             15.472
# 2016 - Nov                                             15.600
# 2016 - Dec                                             15.962
#
#             Mill use  (in  480-lb netweright in million bales)  Exports
# Year-Month
# 2009 - Jan                                              4.170    11.550
# 2009 - Feb                                              3.870    11.100
# 2009 - Mar                                              3.720    11.650
# 2009 - Apr                                              3.620    12.225
# 2009 - May                                              3.520    12.300
# ...                                                       ...       ...
# 2016 - Aug                                              3.575    10.950
# 2016 - Sep                                              3.475    10.950
# 2016 - Oct                                              3.475    11.425
# 2016 - Nov                                              3.475    11.425
# 2016 - Dec                                              3.275    11.600
#
# [96 rows x 17 columns]

# %%
me_df.describe()
# Out:
#        Monthly Nominal GDP Index (inMillion$)  \
# count                               96.000000
# mean                             16490.078125
# std                               1427.554038
# min                              14317.372922
# 25%                              15210.701514
# 50%                              16422.454368
# 75%                              17772.032416
# max                              19015.393408
#
#        Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# count                            96.000000   96.000000          96.000000
# mean                          15548.932194  252.372552           7.442708
# std                             773.076316    9.290857           1.766397
# min                           14345.676097  233.402000           4.600000
# 25%                           14919.668252  242.474500           5.675000
# 50%                           15442.996869  254.680500           7.750000
# 75%                           16262.237629  260.381500           9.000000
# max                           16918.050624  265.421000          10.000000
#
#        CommercialBankInterestRateonCreditCardPlans  \
# count                                    96.000000
# mean                                     12.519479
# std                                       0.722375
# min                                      11.820000
# 25%                                      11.950000
# 50%                                      12.220000
# 75%                                      13.057500
# max                                      14.260000
#
#        Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# count                                          96.000000
# mean                                           10.447604
# std                                             0.560651
# min                                             9.450000
# 25%                                            10.030000
# 50%                                            10.470000
# 75%                                            10.940000
# max                                            11.440000
#
#        Earnings or wages  in dollars per hour  \
# count                               96.000000
# mean                                23.793229
# std                                  1.147167
# min                                 21.960000
# 25%                                 22.797500
# 50%                                 23.800000
# 75%                                 24.772500
# max                                 26.040000
#
#        Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  \
# count                                       96.000000    96.000000
# mean                                        91.034479     0.615521
# std                                         33.613974     6.919387
# min                                         51.500000   -23.590000
# 25%                                         70.377500    -2.400000
# 50%                                         83.905000     0.350000
# 75%                                         93.322500     3.482500
# max                                        229.670000    22.850000
#
#        Average upland planted(million acres)  \
# count                              96.000000
# mean                               10.647698
# std                                 1.728418
# min                                 8.398000
# 25%                                 9.296000
# 50%                                10.260500
# 75%                                11.412250
# max                                14.431000
#
#        Average upland harvested(million acres)  yieldperharvested acre  \
# count                                96.000000               96.000000
# mean                                  8.851885              791.843750
# std                                   1.102847               25.753621
# min                                   7.345000              747.000000
# 25%                                   7.586000              772.750000
# 50%                                   9.156500              790.000000
# 75%                                   9.654500              807.000000
# max                                  10.577000              869.000000
#
#        Production (in  480-lb netweright in million bales)  \
# count                                          96.000000
# mean                                           14.616010
# std                                             2.007579
# min                                            11.751000
# 25%                                            12.551000
# 50%                                            14.959000
# 75%                                            16.250000
# max                                            18.375000
#
#        Mill use  (in  480-lb netweright in million bales)    Exports
# count                                          96.000000   96.000000
# mean                                            3.556104   11.061615
# std                                             0.158263    1.710573
# min                                             3.275000    8.500000
# 25%                                             3.410000    9.742500
# 50%                                             3.572500   10.637500
# 75%                                             3.675000   11.493750
# max                                             4.170000   15.280000

# %%
me_df['PartyInPower'].unique()
# Out:
# array(['Democrats'], dtype=object)

# %%
me_df.drop(columns=['PartyInPower'], inplace=True)

# %%
me_df['AdvertisingExpenses (in Thousand Dollars)'].unique()
# Out:
# array([137, 200, '?', 214, 248, 116, 165, 150, 221, 208, 201, 183],
#       dtype=object)

# %%
def convert_to_float(value):
    try:
        return float(value)
    except ValueError:
        return None
    
me_df['AdvertisingExpenses (in Thousand Dollars)'] = me_df['AdvertisingExpenses (in Thousand Dollars)'].apply(convert_to_float)
me_df['AdvertisingExpenses (in Thousand Dollars)'].fillna(me_df['AdvertisingExpenses (in Thousand Dollars)'].median(), inplace=True)
me_df['AdvertisingExpenses (in Thousand Dollars)'].unique()
# Out:
# array([137., 200., 214., 248., 116., 165., 150., 221., 208., 201., 183.])

# %%
scaler = StandardScaler()
me_df = pd.DataFrame(scaler.fit_transform(me_df), columns=me_df.columns, index=me_df.index)
me_df = me_df.loc[:'2014 - Dec']
me_df
# Out:
#             Monthly Nominal GDP Index (inMillion$)  \
# Year-Month
# 2009 - Jan                               -1.456465
# 2009 - Feb                               -1.479388
# 2009 - Mar                               -1.513539
# 2009 - Apr                               -1.523318
# 2009 - May                               -1.509876
# ...                                            ...
# 2014 - Aug                                0.841179
# 2014 - Sep                                0.802955
# 2014 - Oct                                0.858643
# 2014 - Nov                                0.898007
# 2014 - Dec                                0.875253
#
#             Monthly Real GDP Index (inMillion$)       CPI  unemployment rate  \
# Year-Month
# 2009 - Jan                            -1.484812 -2.052570           0.203333
# 2009 - Feb                            -1.537965 -1.916133           0.487881
# 2009 - Mar                            -1.556676 -1.872421           0.715520
# 2009 - Apr                            -1.556917 -1.816699           0.886249
# 2009 - May                            -1.535433 -1.774177           1.113887
# ...                                         ...       ...                ...
# 2014 - Aug                             0.841944  0.941585          -0.707220
# 2014 - Sep                             0.759541  0.941477          -0.877949
# 2014 - Oct                             0.842457  0.879371          -0.991769
# 2014 - Nov                             0.902584  0.758406          -0.934859
# 2014 - Dec                             0.874140  0.617533          -1.048678
#
#             CommercialBankInterestRateonCreditCardPlans  \
# Year-Month
# 2009 - Jan                                    -0.681154
# 2009 - Feb                                     0.626940
# 2009 - Mar                                     0.626940
# 2009 - Apr                                     0.626940
# 2009 - May                                     1.113996
# ...                                                 ...
# 2014 - Aug                                    -0.973387
# 2014 - Sep                                    -0.973387
# 2014 - Oct                                    -0.973387
# 2014 - Nov                                    -0.736817
# 2014 - Dec                                    -0.736817
#
#             Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# Year-Month
# 2009 - Jan                                           1.779368
# 2009 - Feb                                           1.080097
# 2009 - Mar                                           1.080097
# 2009 - Apr                                           1.080097
# 2009 - May                                           1.438698
# ...                                                       ...
# 2014 - Aug                                           0.506336
# 2014 - Sep                                           0.506336
# 2014 - Oct                                           0.506336
# 2014 - Nov                                           0.040156
# 2014 - Dec                                           0.040156
#
#             Earnings or wages  in dollars per hour  \
# Year-Month
# 2009 - Jan                               -1.527572
# 2009 - Feb                               -1.378603
# 2009 - Mar                               -1.378603
# 2009 - Apr                               -1.457469
# 2009 - May                               -1.536334
# ...                                            ...
# 2014 - Aug                                0.461603
# 2014 - Sep                                0.619335
# 2014 - Oct                                0.636861
# 2014 - Nov                                0.864696
# 2014 - Dec                                0.698201
#
#             AdvertisingExpenses (in Thousand Dollars)  \
# Year-Month
# 2009 - Jan                                  -4.508031
# 2009 - Feb                                   0.120143
# 2009 - Mar                                   0.120143
# 2009 - Apr                                   1.148626
# 2009 - May                                   0.120143
# ...                                               ...
# 2014 - Aug                                   0.120143
# 2014 - Sep                                   0.120143
# 2014 - Oct                                   0.120143
# 2014 - Nov                                   0.120143
# 2014 - Dec                                   0.120143
#
#             Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  \
# Year-Month
# 2009 - Jan                                       -0.996891     0.494603
# 2009 - Feb                                       -1.071356    -0.717033
# 2009 - Mar                                       -1.182306    -1.065705
# 2009 - Apr                                       -1.024404     1.399698
# 2009 - May                                       -0.869792     1.234079
# ...                                                    ...          ...
# 2014 - Aug                                       -0.509428    -1.795012
# 2014 - Sep                                       -0.527970    -0.211458
# 2014 - Oct                                       -0.618883    -0.690883
# 2014 - Nov                                       -0.702918    -0.669091
# 2014 - Dec                                       -0.679890     0.076196
#
#             Average upland planted(million acres)  \
# Year-Month
# 2009 - Jan                              -0.786149
# 2009 - Feb                              -0.786149
# 2009 - Mar                              -0.786149
# 2009 - Apr                              -0.786149
# 2009 - May                              -0.785567
# ...                                           ...
# 2014 - Aug                               0.315985
# 2014 - Sep                               0.099048
# 2014 - Oct                               0.099048
# 2014 - Nov                               0.099048
# 2014 - Dec                               0.099048
#
#             Average upland harvested(million acres)  yieldperharvested acre  \
# Year-Month
# 2009 - Jan                                -1.178470                0.279332
# 2009 - Feb                                -1.178470                0.279332
# 2009 - Mar                                -1.178470                0.279332
# 2009 - Apr                                -1.178470               -0.189068
# 2009 - May                                -1.323400                0.435465
# ...                                             ...                     ...
# 2014 - Aug                                 1.105759                0.630632
# 2014 - Sep                                 0.765768               -0.071968
# 2014 - Oct                                 0.765768               -0.618434
# 2014 - Nov                                 0.765768               -0.345201
# 2014 - Dec                                 0.765768               -1.242967
#
#             Production (in  480-lb netweright in million bales)  \
# Year-Month
# 2009 - Jan                                          -1.014979
# 2009 - Feb                                          -1.014979
# 2009 - Mar                                          -1.014979
# 2009 - Apr                                          -1.109617
# 2009 - May                                          -1.117628
# ...                                                       ...
# 2014 - Aug                                           1.166689
# 2014 - Sep                                           0.672972
# 2014 - Oct                                           0.531266
# 2014 - Nov                                           0.602370
# 2014 - Dec                                           0.365025
#
#             Mill use  (in  480-lb netweright in million bales)   Exports
# Year-Month
# 2009 - Jan                                           3.899323   0.287009
# 2009 - Feb                                           1.993793   0.022558
# 2009 - Mar                                           1.041028   0.345775
# 2009 - Apr                                           0.405851   0.683684
# 2009 - May                                          -0.229325   0.727760
# ...                                                       ...        ...
# 2014 - Aug                                           1.390375  -0.535727
# 2014 - Sep                                           1.390375  -0.947094
# 2014 - Oct                                           1.390375  -0.947094
# 2014 - Nov                                           1.390375  -0.947094
# 2014 - Dec                                           1.390375  -0.947094
#
# [72 rows x 16 columns]

# %% [markdown]
# ## Weather data

# %%
def load_sheet(year):
    path = '/kaggle/input/walmart-sales-prediction-pune-march-2023/WeatherData.xlsx'
    temp_df = pd.read_excel('/kaggle/input/walmart-sales-prediction-pune-march-2023/WeatherData.xlsx', year)
    temp_df['Year-Month'] = year + " - " + temp_df['Month']
    temp_df = temp_df.set_index('Year-Month').drop(columns=['Year', 'Month'])
    return temp_df

# %%
wth_df = load_sheet('2009')
for year in ('2010', '2011', '2012', '2013', '2014'):
    wth_df = pd.concat([wth_df, load_sheet(year)], axis=0)
wth_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2190 entries, 2009 - Jan to 2014 - Dec
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Day                          2190 non-null   int64
#  1   Temp high (°C)               2190 non-null   object
#  2   Temp avg (°C)                2190 non-null   object
#  3   Temp low (°C)                2190 non-null   object
#  4   Dew Point high (°C)          2190 non-null   object
#  5   Dew Point avg (°C)           2190 non-null   object
#  6   Dew Point low (°C)           2190 non-null   object
#  7   Humidity (%) high            2190 non-null   object
#  8   Humidity (%) avg             2190 non-null   object
#  9   Humidity (%) low             2190 non-null   object
#  10  Sea Level Press. (hPa) high  2190 non-null   object
#  11  Sea Level Press. (hPa) avg   2190 non-null   object
#  12  Sea Level Press. (hPa) low   2190 non-null   object
#  13  Visibility (km) high         2190 non-null   object
#  14  Visibility (km) avg          2190 non-null   object
#  15  Visibility (km) low          2190 non-null   object
#  16  Wind (km/h) low              2190 non-null   object
#  17  Wind (km/h) avg              2190 non-null   object
#  18  Wind (km/h) high             2190 non-null   object
#  19  Precip. (mm) sum             2190 non-null   object
#  20  WeatherEvent                 779 non-null    object
# dtypes: int64(1), object(20)
# memory usage: 376.4+ KB

# %%
wth_df.drop(columns=['Day'], inplace=True)

# %%
def to_float(text):
    try: 
        value = float(text)
    except ValueError:
        pattern = r'- \d+'
        if re.match(pattern, text):
            value = float(text[1:]) * -1
        else:
            value = None
    return value

columns_to_convert = [column for column in wth_df.columns if column != 'WeatherEvent']
wth_df[columns_to_convert] = wth_df[columns_to_convert].applymap(to_float)

# %%
imputer = IterativeImputer(
    estimator=KNeighborsRegressor(),
    max_iter=10,
    random_state=12
)
wth_df[columns_to_convert] = imputer.fit_transform(wth_df[columns_to_convert])

# %%
wth_df = pd.get_dummies(wth_df, columns=['WeatherEvent'])

# %%
wth_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2190 entries, 2009 - Jan to 2014 - Dec
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Temp high (°C)                  2190 non-null   float64
#  1   Temp avg (°C)                   2190 non-null   float64
#  2   Temp low (°C)                   2190 non-null   float64
#  3   Dew Point high (°C)             2190 non-null   float64
#  4   Dew Point avg (°C)              2190 non-null   float64
#  5   Dew Point low (°C)              2190 non-null   float64
#  6   Humidity (%) high               2190 non-null   float64
#  7   Humidity (%) avg                2190 non-null   float64
#  8   Humidity (%) low                2190 non-null   float64
#  9   Sea Level Press. (hPa) high     2190 non-null   float64
#  10  Sea Level Press. (hPa) avg      2190 non-null   float64
#  11  Sea Level Press. (hPa) low      2190 non-null   float64
#  12  Visibility (km) high            2190 non-null   float64
#  13  Visibility (km) avg             2190 non-null   float64
#  14  Visibility (km) low             2190 non-null   float64
#  15  Wind (km/h) low                 2190 non-null   float64
#  16  Wind (km/h) avg                 2190 non-null   float64
#  17  Wind (km/h) high                2190 non-null   float64
#  18  Precip. (mm) sum                2190 non-null   float64
#  19  WeatherEvent_Fog                2190 non-null   uint8
#  20  WeatherEvent_Fog , Rain         2190 non-null   uint8
#  21  WeatherEvent_Fog , Rain , Snow  2190 non-null   uint8
#  22  WeatherEvent_Fog , Snow         2190 non-null   uint8
#  23  WeatherEvent_Rain               2190 non-null   uint8
#  24  WeatherEvent_Rain , Snow        2190 non-null   uint8
#  25  WeatherEvent_Snow               2190 non-null   uint8
#  26  WeatherEvent_Thunderstorm       2190 non-null   uint8
# dtypes: float64(19), uint8(8)
# memory usage: 359.3+ KB

# %%
wth_df = wth_df.groupby(wth_df.index).agg({
    'Temp high (°C)': 'max',
    'Temp avg (°C)': 'mean',
    'Temp low (°C)': 'min',
    'Dew Point high (°C)': 'max',
    'Dew Point avg (°C)': 'mean',
    'Dew Point low (°C)': 'min',
    'Humidity\xa0(%) high': 'max',
    'Humidity\xa0(%) avg': 'mean',
    'Humidity\xa0(%) low': 'min',
    'Sea Level Press.\xa0(hPa) high': 'max',
    'Sea Level Press.\xa0(hPa) avg': 'mean',
    'Sea Level Press.\xa0(hPa) low': 'min',
    'Visibility\xa0(km) high': 'max',
    'Visibility\xa0(km) avg': 'mean',
    'Visibility\xa0(km) low': 'min',
    'Wind\xa0(km/h) low': 'min',
    'Wind\xa0(km/h) avg': 'mean',
    'Wind\xa0(km/h) high': 'max',
    'Precip.\xa0(mm) sum': 'sum',
    'WeatherEvent_Fog': 'sum',
    'WeatherEvent_Fog , Rain': 'sum',
    'WeatherEvent_Fog , Rain , Snow': 'sum',
    'WeatherEvent_Fog , Snow': 'sum',
    'WeatherEvent_Rain': 'sum',
    'WeatherEvent_Rain , Snow': 'sum',
    'WeatherEvent_Snow': 'sum',
    'WeatherEvent_Thunderstorm': 'sum',
})
wth_df
# Out:
#             Temp high (°C)  Temp avg (°C)  Temp low (°C)  Dew Point high (°C)  \
# Year-Month
# 2009 - Apr            33.0      12.733333            1.0                 14.0
# 2009 - Aug            33.0      24.387097           17.0                 25.0
# 2009 - Dec            19.0       2.354839           -9.0                 16.0
# 2009 - Feb            18.0       2.785714          -11.0                 11.0
# 2009 - Jan             8.0      -2.096774          -14.0                  4.0
# ...                    ...            ...            ...                  ...
# 2014 - Mar            19.0       2.806452          -13.0                 10.0
# 2014 - May            30.0      17.612903            5.0                 18.0
# 2014 - Nov            21.0       7.533333           -6.0                 16.0
# 2014 - Oct            25.0      15.741935            6.0                 20.0
# 2014 - Sep            33.0      21.366667           11.0                 23.0
#
#             Dew Point avg (°C)  Dew Point low (°C)  Humidity (%) high  \
# Year-Month
# 2009 - Apr            2.533333               -12.0              100.0
# 2009 - Aug           18.483871                 8.0              100.0
# 2009 - Dec           -4.677419               -21.0              100.0
# 2009 - Feb           -6.392857               -19.0              100.0
# 2009 - Jan           -9.903226               -22.0              100.0
# ...                        ...                 ...                ...
# 2014 - Mar           -8.258065               -25.0              100.0
# 2014 - May            8.096774                -7.0               97.0
# 2014 - Nov           -1.766667               -17.0               93.0
# 2014 - Oct            8.580645                -4.0               93.0
# 2014 - Sep           13.266667                 3.0               94.0
#
#             Humidity (%) avg  Humidity (%) low  Sea Level Press. (hPa) high  \
# Year-Month
# 2009 - Apr         55.700000              16.0                       1033.0
# 2009 - Aug         72.483871              35.0                       1025.0
# 2009 - Dec         61.741935              23.0                       1034.0
# 2009 - Feb         54.000000              20.0                       1032.0
# 2009 - Jan         57.354839              22.0                       1036.0
# ...                      ...               ...                          ...
# 2014 - Mar         47.322581              19.0                       1037.0
# 2014 - May         59.967742              18.0                       1030.0
# 2014 - Nov         54.866667              17.0                       1033.0
# 2014 - Oct         63.193548              32.0                       1027.0
# 2014 - Sep         62.400000              31.0                       1035.0
#
#             ...  Wind (km/h) high  Precip. (mm) sum  WeatherEvent_Fog  \
# Year-Month  ...
# 2009 - Apr  ...              61.0           119.424                 0
# 2009 - Aug  ...              64.0           111.048                 0
# 2009 - Dec  ...              64.0           184.650                 0
# 2009 - Feb  ...              77.0            21.952                 0
# 2009 - Jan  ...              60.0            78.086                 0
# ...         ...               ...               ...               ...
# 2014 - Mar  ...              61.0            89.160                 0
# 2014 - May  ...              55.0           235.970                 0
# 2014 - Nov  ...              58.0           115.830                 1
# 2014 - Oct  ...              66.0           145.880                 0
# 2014 - Sep  ...              56.0            46.480                 0
#
#             WeatherEvent_Fog , Rain  WeatherEvent_Fog , Rain , Snow  \
# Year-Month
# 2009 - Apr                        1                               0
# 2009 - Aug                        5                               0
# 2009 - Dec                        0                               0
# 2009 - Feb                        0                               0
# 2009 - Jan                        0                               2
# ...                             ...                             ...
# 2014 - Mar                        0                               0
# 2014 - May                        3                               0
# 2014 - Nov                        1                               0
# 2014 - Oct                        3                               0
# 2014 - Sep                        1                               0
#
#             WeatherEvent_Fog , Snow  WeatherEvent_Rain  \
# Year-Month
# 2009 - Apr                        0                 11
# 2009 - Aug                        0                  8
# 2009 - Dec                        3                  6
# 2009 - Feb                        1                  4
# 2009 - Jan                        2                  3
# ...                             ...                ...
# 2014 - Mar                        0                  6
# 2014 - May                        0                  9
# 2014 - Nov                        0                  6
# 2014 - Oct                        0                 11
# 2014 - Sep                        0                  6
#
#             WeatherEvent_Rain , Snow  WeatherEvent_Snow  \
# Year-Month
# 2009 - Apr                         0                  0
# 2009 - Aug                         0                  0
# 2009 - Dec                         2                  0
# 2009 - Feb                         1                  0
# 2009 - Jan                         0                  3
# ...                              ...                ...
# 2014 - Mar                         0                  2
# 2014 - May                         0                  0
# 2014 - Nov                         1                  1
# 2014 - Oct                         0                  0
# 2014 - Sep                         0                  0
#
#             WeatherEvent_Thunderstorm
# Year-Month
# 2009 - Apr                          0
# 2009 - Aug                          0
# 2009 - Dec                          0
# 2009 - Feb                          0
# 2009 - Jan                          0
# ...                               ...
# 2014 - Mar                          0
# 2014 - May                          0
# 2014 - Nov                          0
# 2014 - Oct                          0
# 2014 - Sep                          0
#
# [72 rows x 27 columns]

# %%
scaler = StandardScaler()
wth_df = pd.DataFrame(scaler.fit_transform(wth_df), columns=wth_df.columns, index=wth_df.index)
wth_df
# Out:
#             Temp high (°C)  Temp avg (°C)  Temp low (°C)  Dew Point high (°C)  \
# Year-Month
# 2009 - Apr        0.884439      -0.066004      -0.164120            -0.633104
# 2009 - Aug        0.884439       1.269856       1.479933             1.348786
# 2009 - Dec       -0.860208      -1.255681      -1.191653            -0.272760
# 2009 - Feb       -0.984826      -1.206290      -1.397159            -1.173619
# 2009 - Jan       -2.231002      -1.765965      -1.705419            -2.434822
# ...                    ...            ...            ...                  ...
# 2014 - Mar       -0.860208      -1.203913      -1.602666            -1.353791
# 2014 - May        0.510586       0.493337       0.246893             0.087584
# 2014 - Nov       -0.610973      -0.662075      -0.883393            -0.272760
# 2014 - Oct       -0.112502       0.278869       0.349647             0.447927
# 2014 - Sep        0.884439       0.923627       0.863413             0.988443
#
#             Dew Point avg (°C)  Dew Point low (°C)  Humidity (%) high  \
# Year-Month
# 2009 - Apr           -0.319977           -0.385267           0.423678
# 2009 - Aug            1.457125            1.482692           0.423678
# 2009 - Dec           -1.123351           -1.225848           0.423678
# 2009 - Feb           -1.314474           -1.039052           0.423678
# 2009 - Jan           -1.705575           -1.319246           0.423678
# ...                        ...                 ...                ...
# 2014 - Mar           -1.522283           -1.599440           0.423678
# 2014 - May            0.299864            0.081723          -0.922123
# 2014 - Nov           -0.799054           -0.852256          -2.716524
# 2014 - Oct            0.353774            0.361917          -2.716524
# 2014 - Sep            0.875859            1.015703          -2.267924
#
#             Humidity (%) avg  Humidity (%) low  Sea Level Press. (hPa) high  \
# Year-Month
# 2009 - Apr         -1.101324         -1.283803                     0.433336
# 2009 - Aug          1.603283          1.802739                    -1.136485
# 2009 - Dec         -0.127707         -0.146656                     0.629563
# 2009 - Feb         -1.375268         -0.634005                     0.237108
# 2009 - Jan         -0.834658         -0.309105                     1.022018
# ...                      ...               ...                          ...
# 2014 - Mar         -2.451289         -0.796454                     1.218246
# 2014 - May         -0.413606         -0.958904                    -0.155347
# 2014 - Nov         -1.235610         -1.121353                     0.433336
# 2014 - Oct          0.106211          1.315390                    -0.744029
# 2014 - Sep         -0.021664          1.152941                     0.825791
#
#             ...  Wind (km/h) high  Precip. (mm) sum  WeatherEvent_Fog  \
# Year-Month  ...
# 2009 - Apr  ...         -0.010382          0.081156         -0.408248
# 2009 - Aug  ...          0.176500         -0.035682         -0.408248
# 2009 - Dec  ...          0.176500          0.990999         -0.408248
# 2009 - Feb  ...          0.986325         -1.278490         -0.408248
# 2009 - Jan  ...         -0.072677         -0.495472         -0.408248
# ...         ...               ...               ...               ...
# 2014 - Mar  ...         -0.010382         -0.340999         -0.408248
# 2014 - May  ...         -0.384147          1.706866         -0.408248
# 2014 - Nov  ...         -0.197265          0.031023          2.041241
# 2014 - Oct  ...          0.301089          0.450193         -0.408248
# 2014 - Sep  ...         -0.321853         -0.936346         -0.408248
#
#             WeatherEvent_Fog , Rain  WeatherEvent_Fog , Rain , Snow  \
# Year-Month
# 2009 - Apr                -0.448322                       -0.353553
# 2009 - Aug                 1.942728                       -0.353553
# 2009 - Dec                -1.046085                       -0.353553
# 2009 - Feb                -1.046085                       -0.353553
# 2009 - Jan                -1.046085                        2.828427
# ...                             ...                             ...
# 2014 - Mar                -1.046085                       -0.353553
# 2014 - May                 0.747203                       -0.353553
# 2014 - Nov                -0.448322                       -0.353553
# 2014 - Oct                 0.747203                       -0.353553
# 2014 - Sep                -0.448322                       -0.353553
#
#             WeatherEvent_Fog , Snow  WeatherEvent_Rain  \
# Year-Month
# 2009 - Apr                -0.439057           1.194824
# 2009 - Aug                -0.439057           0.235411
# 2009 - Dec                 2.524578          -0.404197
# 2009 - Feb                 0.548821          -1.043805
# 2009 - Jan                 1.536700          -1.363610
# ...                             ...                ...
# 2014 - Mar                -0.439057          -0.404197
# 2014 - May                -0.439057           0.555216
# 2014 - Nov                -0.439057          -0.404197
# 2014 - Oct                -0.439057           1.194824
# 2014 - Sep                -0.439057          -0.404197
#
#             WeatherEvent_Rain , Snow  WeatherEvent_Snow  \
# Year-Month
# 2009 - Apr                 -0.477396          -0.471405
# 2009 - Aug                 -0.477396          -0.471405
# 2009 - Dec                  2.796177          -0.471405
# 2009 - Feb                  1.159390          -0.471405
# 2009 - Jan                 -0.477396           1.649916
# ...                              ...                ...
# 2014 - Mar                 -0.477396           0.942809
# 2014 - May                 -0.477396          -0.471405
# 2014 - Nov                  1.159390           0.235702
# 2014 - Oct                 -0.477396          -0.471405
# 2014 - Sep                 -0.477396          -0.471405
#
#             WeatherEvent_Thunderstorm
# Year-Month
# 2009 - Apr                  -0.118678
# 2009 - Aug                  -0.118678
# 2009 - Dec                  -0.118678
# 2009 - Feb                  -0.118678
# 2009 - Jan                  -0.118678
# ...                               ...
# 2014 - Mar                  -0.118678
# 2014 - May                  -0.118678
# 2014 - Nov                  -0.118678
# 2014 - Oct                  -0.118678
# 2014 - Sep                  -0.118678
#
# [72 rows x 27 columns]

# %% [markdown]
# ## Events Data

# %%
ev_df = pd.read_excel('/kaggle/input/walmart-sales-prediction-pune-march-2023/Events_HolidaysData.xlsx', 'Sheet1')
ev_df
# Out:
#      Year  MonthDate                       Event      DayCategory
# 0    2009 2001-01-01              New Year's Day  Federal Holiday
# 1    2009 2019-01-01  Martin Luther King Jr. Day  Federal Holiday
# 2    2009 2014-02-01             Valentine's Day            Event
# 3    2009 2016-02-01             Presidents' Day  Federal Holiday
# 4    2009 2012-04-01               Easter Sunday            Event
# ..    ...        ...                         ...              ...
# 145  2016 2024-11-01            Thanksgiving Day  Federal Holiday
# 146  2016 2024-12-01               Christmas Eve            Event
# 147  2016 2025-12-01               Christmas Day  Federal Holiday
# 148  2016 2026-12-01    'Christmas Day' observed  Federal Holiday
# 149  2016 1931-12-01              New Year's Eve            Event
#
# [150 rows x 4 columns]

# %%
ev_df = ev_df[ev_df['Year'] < 2015]
ev_df
# Out:
#      Year  MonthDate                       Event      DayCategory
# 0    2009 2001-01-01              New Year's Day  Federal Holiday
# 1    2009 2019-01-01  Martin Luther King Jr. Day  Federal Holiday
# 2    2009 2014-02-01             Valentine's Day            Event
# 3    2009 2016-02-01             Presidents' Day  Federal Holiday
# 4    2009 2012-04-01               Easter Sunday            Event
# ..    ...        ...                         ...              ...
# 105  2014 2011-11-01                Veterans Day  Federal Holiday
# 106  2014 2027-11-01            Thanksgiving Day  Federal Holiday
# 107  2014 2024-12-01               Christmas Eve            Event
# 108  2014 2025-12-01               Christmas Day  Federal Holiday
# 109  2014 1931-12-01              New Year's Eve            Event
#
# [110 rows x 4 columns]

# %%
def yearmonth(row):
    months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    return str(row['Year']) + ' - ' + months[int(row['MonthDate'].month) - 1] 


ev_df['Year-Month'] =  ev_df.apply(yearmonth, axis=1)
ev_df.drop(columns=['Year', 'MonthDate', 'Event'], inplace=True)
ev_df.set_index('Year-Month', inplace=True)
ev_df
# Out:
# /tmp/ipykernel_21/1340755218.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_df['Year-Month'] =  ev_df.apply(yearmonth, axis=1)
# /tmp/ipykernel_21/1340755218.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_df.drop(columns=['Year', 'MonthDate', 'Event'], inplace=True)
#                 DayCategory
# Year-Month
# 2009 - Jan  Federal Holiday
# 2009 - Jan  Federal Holiday
# 2009 - Feb            Event
# 2009 - Feb  Federal Holiday
# 2009 - Apr            Event
# ...                     ...
# 2014 - Nov  Federal Holiday
# 2014 - Nov  Federal Holiday
# 2014 - Dec            Event
# 2014 - Dec  Federal Holiday
# 2014 - Dec            Event
#
# [110 rows x 1 columns]

# %%
ev_df = pd.get_dummies(ev_df, columns=['DayCategory'])
ev_df
# Out:
#             DayCategory_Event  DayCategory_Federal Holiday
# Year-Month
# 2009 - Jan                  0                            1
# 2009 - Jan                  0                            1
# 2009 - Feb                  1                            0
# 2009 - Feb                  0                            1
# 2009 - Apr                  1                            0
# ...                       ...                          ...
# 2014 - Nov                  0                            1
# 2014 - Nov                  0                            1
# 2014 - Dec                  1                            0
# 2014 - Dec                  0                            1
# 2014 - Dec                  1                            0
#
# [110 rows x 2 columns]

# %%
ev_df = ev_df.groupby(ev_df.index).agg({
    'DayCategory_Event': 'sum',
    'DayCategory_Federal Holiday': 'sum'
})

# %% [markdown]
# ## JOIN DATASETS

# %%
tempdf = wth_df.merge(me_df, left_index=True, right_index=True)

# %%
df = pd.merge(tempdf, ev_df, on='Year-Month', how='left')

# %%
df[['DayCategory_Event', 'DayCategory_Federal Holiday']] = df[['DayCategory_Event', 'DayCategory_Federal Holiday']].fillna(0)

# %%
scaler = StandardScaler()
df[['DayCategory_Event', 'DayCategory_Federal Holiday']] = scaler.fit_transform(df[['DayCategory_Event', 'DayCategory_Federal Holiday']])
df
# Out:
#             Temp high (°C)  Temp avg (°C)  Temp low (°C)  Dew Point high (°C)  \
# Year-Month
# 2009 - Apr        0.884439      -0.066004      -0.164120            -0.633104
# 2009 - Aug        0.884439       1.269856       1.479933             1.348786
# 2009 - Dec       -0.860208      -1.255681      -1.191653            -0.272760
# 2009 - Feb       -0.984826      -1.206290      -1.397159            -1.173619
# 2009 - Jan       -2.231002      -1.765965      -1.705419            -2.434822
# ...                    ...            ...            ...                  ...
# 2014 - Mar       -0.860208      -1.203913      -1.602666            -1.353791
# 2014 - May        0.510586       0.493337       0.246893             0.087584
# 2014 - Nov       -0.610973      -0.662075      -0.883393            -0.272760
# 2014 - Oct       -0.112502       0.278869       0.349647             0.447927
# 2014 - Sep        0.884439       0.923627       0.863413             0.988443
#
#             Dew Point avg (°C)  Dew Point low (°C)  Humidity (%) high  \
# Year-Month
# 2009 - Apr           -0.319977           -0.385267           0.423678
# 2009 - Aug            1.457125            1.482692           0.423678
# 2009 - Dec           -1.123351           -1.225848           0.423678
# 2009 - Feb           -1.314474           -1.039052           0.423678
# 2009 - Jan           -1.705575           -1.319246           0.423678
# ...                        ...                 ...                ...
# 2014 - Mar           -1.522283           -1.599440           0.423678
# 2014 - May            0.299864            0.081723          -0.922123
# 2014 - Nov           -0.799054           -0.852256          -2.716524
# 2014 - Oct            0.353774            0.361917          -2.716524
# 2014 - Sep            0.875859            1.015703          -2.267924
#
#             Humidity (%) avg  Humidity (%) low  Sea Level Press. (hPa) high  \
# Year-Month
# 2009 - Apr         -1.101324         -1.283803                     0.433336
# 2009 - Aug          1.603283          1.802739                    -1.136485
# 2009 - Dec         -0.127707         -0.146656                     0.629563
# 2009 - Feb         -1.375268         -0.634005                     0.237108
# 2009 - Jan         -0.834658         -0.309105                     1.022018
# ...                      ...               ...                          ...
# 2014 - Mar         -2.451289         -0.796454                     1.218246
# 2014 - May         -0.413606         -0.958904                    -0.155347
# 2014 - Nov         -1.235610         -1.121353                     0.433336
# 2014 - Oct          0.106211          1.315390                    -0.744029
# 2014 - Sep         -0.021664          1.152941                     0.825791
#
#             ...  Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  \
# Year-Month  ...
# 2009 - Apr  ...                                       -1.024404     1.399698
# 2009 - Aug  ...                                       -0.800710    -0.210005
# 2009 - Dec  ...                                       -0.426290     0.923180
# 2009 - Feb  ...                                       -1.071356    -0.717033
# 2009 - Jan  ...                                       -0.996891     0.494603
# ...         ...                                             ...          ...
# 2014 - Mar  ...                                        0.176908     0.358040
# 2014 - May  ...                                        0.050108    -0.318966
# 2014 - Nov  ...                                       -0.702918    -0.669091
# 2014 - Oct  ...                                       -0.618883    -0.690883
# 2014 - Sep  ...                                       -0.527970    -0.211458
#
#             Average upland planted(million acres)  \
# Year-Month
# 2009 - Apr                              -0.786149
# 2009 - Aug                              -1.013555
# 2009 - Dec                              -0.964700
# 2009 - Feb                              -0.786149
# 2009 - Jan                              -0.786149
# ...                                           ...
# 2014 - Mar                              -0.256892
# 2014 - May                              -0.256892
# 2014 - Nov                               0.099048
# 2014 - Oct                               0.099048
# 2014 - Sep                               0.099048
#
#             Average upland harvested(million acres)  yieldperharvested acre  \
# Year-Month
# 2009 - Apr                                -1.178470               -0.189068
# 2009 - Aug                                -1.123780                0.669665
# 2009 - Dec                                -1.153860               -0.696501
# 2009 - Feb                                -1.178470                0.279332
# 2009 - Jan                                -1.178470                0.279332
# ...                                             ...                     ...
# 2014 - Mar                                -1.264152                0.591599
# 2014 - May                                -1.373532                0.396432
# 2014 - Nov                                 0.765768               -0.345201
# 2014 - Oct                                 0.765768               -0.618434
# 2014 - Sep                                 0.765768               -0.071968
#
#             Production (in  480-lb netweright in million bales)  \
# Year-Month
# 2009 - Apr                                          -1.109617
# 2009 - Aug                                          -0.889297
# 2009 - Dec                                          -1.197244
# 2009 - Feb                                          -1.014979
# 2009 - Jan                                          -1.014979
# ...                                                       ...
# 2014 - Mar                                          -1.034007
# 2014 - May                                          -1.172208
# 2014 - Nov                                           0.602370
# 2014 - Oct                                           0.531266
# 2014 - Sep                                           0.672972
#
#             Mill use  (in  480-lb netweright in million bales)   Exports  \
# Year-Month
# 2009 - Apr                                           0.405851   0.683684
# 2009 - Aug                                          -0.546914  -0.800177
# 2009 - Dec                                          -1.182090  -0.374118
# 2009 - Feb                                           1.993793   0.022558
# 2009 - Jan                                           3.899323   0.287009
# ...                                                       ...        ...
# 2014 - Mar                                           0.151781  -0.653260
# 2014 - May                                           0.151781  -0.814869
# 2014 - Nov                                           1.390375  -0.947094
# 2014 - Oct                                           1.390375  -0.947094
# 2014 - Sep                                           1.390375  -0.947094
#
#             DayCategory_Event  DayCategory_Federal Holiday
# Year-Month
# 2009 - Apr           0.591608                    -1.153113
# 2009 - Aug          -0.929670                    -1.153113
# 2009 - Dec           2.112886                     0.104828
# 2009 - Feb           0.591608                     0.104828
# 2009 - Jan          -0.929670                     1.362770
# ...                       ...                          ...
# 2014 - Mar          -0.929670                    -1.153113
# 2014 - May           0.591608                     0.104828
# 2014 - Nov          -0.929670                     1.362770
# 2014 - Oct           0.591608                     0.104828
# 2014 - Sep          -0.929670                     0.104828
#
# [72 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 2009 - Apr to 2014 - Sep
# Data columns (total 45 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Temp high (°C)                                                     72 non-null     float64
#  1   Temp avg (°C)                                                      72 non-null     float64
#  2   Temp low (°C)                                                      72 non-null     float64
#  3   Dew Point high (°C)                                                72 non-null     float64
#  4   Dew Point avg (°C)                                                 72 non-null     float64
#  5   Dew Point low (°C)                                                 72 non-null     float64
#  6   Humidity (%) high                                                  72 non-null     float64
#  7   Humidity (%) avg                                                   72 non-null     float64
#  8   Humidity (%) low                                                   72 non-null     float64
#  9   Sea Level Press. (hPa) high                                        72 non-null     float64
#  10  Sea Level Press. (hPa) avg                                         72 non-null     float64
#  11  Sea Level Press. (hPa) low                                         72 non-null     float64
#  12  Visibility (km) high                                               72 non-null     float64
#  13  Visibility (km) avg                                                72 non-null     float64
#  14  Visibility (km) low                                                72 non-null     float64
#  15  Wind (km/h) low                                                    72 non-null     float64
#  16  Wind (km/h) avg                                                    72 non-null     float64
#  17  Wind (km/h) high                                                   72 non-null     float64
#  18  Precip. (mm) sum                                                   72 non-null     float64
#  19  WeatherEvent_Fog                                                   72 non-null     float64
#  20  WeatherEvent_Fog , Rain                                            72 non-null     float64
#  21  WeatherEvent_Fog , Rain , Snow                                     72 non-null     float64
#  22  WeatherEvent_Fog , Snow                                            72 non-null     float64
#  23  WeatherEvent_Rain                                                  72 non-null     float64
#  24  WeatherEvent_Rain , Snow                                           72 non-null     float64
#  25  WeatherEvent_Snow                                                  72 non-null     float64
#  26  WeatherEvent_Thunderstorm                                          72 non-null     float64
#  27  Monthly Nominal GDP Index (inMillion$)                             72 non-null     float64
#  28  Monthly Real GDP Index (inMillion$)                                72 non-null     float64
#  29  CPI                                                                72 non-null     float64
#  30  unemployment rate                                                  72 non-null     float64
#  31  CommercialBankInterestRateonCreditCardPlans                        72 non-null     float64
#  32  Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  72 non-null     float64
#  33  Earnings or wages  in dollars per hour                             72 non-null     float64
#  34  AdvertisingExpenses (in Thousand Dollars)                          72 non-null     float64
#  35  Cotton Monthly Price - US cents per Pound(lbs)                     72 non-null     float64
#  36  Change(in%)                                                        72 non-null     float64
#  37  Average upland planted(million acres)                              72 non-null     float64
#  38  Average upland harvested(million acres)                            72 non-null     float64
#  39  yieldperharvested acre                                             72 non-null     float64
#  40  Production (in  480-lb netweright in million bales)                72 non-null     float64
#  41  Mill use  (in  480-lb netweright in million bales)                 72 non-null     float64
#  42  Exports                                                            72 non-null     float64
#  43  DayCategory_Event                                                  72 non-null     float64
#  44  DayCategory_Federal Holiday                                        72 non-null     float64
# dtypes: float64(45)
# memory usage: 25.9+ KB

# %%
train
# Out:
#      Year  Month ProductCategory  Sales(In ThousandDollars)
# 0    2009      1   WomenClothing                     1755.0
# 1    2009      1     MenClothing                      524.0
# 2    2009      1   OtherClothing                      936.0
# 3    2009      2   WomenClothing                     1729.0
# 4    2009      2     MenClothing                      496.0
# ..    ...    ...             ...                        ...
# 175  2013     11     MenClothing                      798.0
# 176  2013     11   OtherClothing                     1209.0
# 177  2013     12   WomenClothing                     4865.0
# 178  2013     12     MenClothing                     1085.0
# 179  2013     12   OtherClothing                     1566.0
#
# [180 rows x 4 columns]

# %%
def totext(value):
    months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    return months[value - 1]

train['Year-Month'] = train['Year'].astype(str) + ' - ' + train['Month'].apply(totext)
train.drop(columns=['Year', 'Month'], inplace=True)
train.set_index('Year-Month', inplace=True)
train
# Out:
#            ProductCategory  Sales(In ThousandDollars)
# Year-Month
# 2009 - Jan   WomenClothing                     1755.0
# 2009 - Jan     MenClothing                      524.0
# 2009 - Jan   OtherClothing                      936.0
# 2009 - Feb   WomenClothing                     1729.0
# 2009 - Feb     MenClothing                      496.0
# ...                    ...                        ...
# 2013 - Nov     MenClothing                      798.0
# 2013 - Nov   OtherClothing                     1209.0
# 2013 - Dec   WomenClothing                     4865.0
# 2013 - Dec     MenClothing                     1085.0
# 2013 - Dec   OtherClothing                     1566.0
#
# [180 rows x 2 columns]

# %%
women_clothing = train[train['ProductCategory'] == 'WomenClothing']['Sales(In ThousandDollars)']
men_clothing = train[train['ProductCategory'] == 'MenClothing']['Sales(In ThousandDollars)']
other_clothing = train[train['ProductCategory'] == 'OtherClothing']['Sales(In ThousandDollars)']

train_target = pd.DataFrame({
    'WomenClothing Sales': women_clothing,
    'MenClothing Sales': men_clothing,
    'OtherClothing Sales': other_clothing,
    },
    index=train.index.unique()
)

train_target['WomenClothing Sales'].fillna(train_target['WomenClothing Sales'].mean(), inplace=True)
train_target['MenClothing Sales'].fillna(train_target['MenClothing Sales'].mean(), inplace=True)
train_target['OtherClothing Sales'].fillna(train_target['OtherClothing Sales'].mean(), inplace=True)

# %%
train_data = df.loc[:'2013 - Sep']
test_data = df.loc['2014 - Apr':]
test_data
# Out:
#             Temp high (°C)  Temp avg (°C)  Temp low (°C)  Dew Point high (°C)  \
# Year-Month
# 2014 - Apr       -0.112502      -0.211201      -0.369626            -0.633104
# 2014 - Aug        0.759822       1.181111       1.377179             0.628099
# 2014 - Dec       -0.984826      -0.926584      -0.677886            -0.272760
# 2014 - Feb       -1.607914      -1.492862      -1.397159            -1.894306
# 2014 - Jan       -1.483296      -1.728125      -1.910926            -0.813276
# 2014 - Jul        0.884439       1.303135       1.479933             1.168614
# 2014 - Jun        0.759822       1.042077       1.068920             0.628099
# 2014 - Mar       -0.860208      -1.203913      -1.602666            -1.353791
# 2014 - May        0.510586       0.493337       0.246893             0.087584
# 2014 - Nov       -0.610973      -0.662075      -0.883393            -0.272760
# 2014 - Oct       -0.112502       0.278869       0.349647             0.447927
# 2014 - Sep        0.884439       0.923627       0.863413             0.988443
#
#             Dew Point avg (°C)  Dew Point low (°C)  Humidity (%) high  \
# Year-Month
# 2014 - Apr           -0.539090           -0.478664          -2.716524
# 2014 - Aug            1.007878            1.389294          -2.716524
# 2014 - Dec           -0.738795           -0.945654           0.423678
# 2014 - Feb           -1.473635           -1.786236          -1.370723
# 2014 - Jan           -1.649509           -1.786236           0.423678
# 2014 - Jul            1.230704            1.389294           0.423678
# 2014 - Jun            0.942707            0.828907           0.423678
# 2014 - Mar           -1.522283           -1.599440           0.423678
# 2014 - May            0.299864            0.081723          -0.922123
# 2014 - Nov           -0.799054           -0.852256          -2.716524
# 2014 - Oct            0.353774            0.361917          -2.716524
# 2014 - Sep            0.875859            1.015703          -2.267924
#
#             Humidity (%) avg  Humidity (%) low  Sea Level Press. (hPa) high  \
# Year-Month
# 2014 - Apr         -1.450468         -1.933601                     2.003156
# 2014 - Aug         -0.351228          0.503143                    -1.136485
# 2014 - Dec          0.350525          0.503143                     1.610701
# 2014 - Feb         -0.615592          0.015794                     0.825791
# 2014 - Jan         -0.499723          0.015794                     1.610701
# 2014 - Jul          0.230967          0.990491                    -1.332712
# 2014 - Jun          0.010564         -0.471555                    -0.547802
# 2014 - Mar         -2.451289         -0.796454                     1.218246
# 2014 - May         -0.413606         -0.958904                    -0.155347
# 2014 - Nov         -1.235610         -1.121353                     0.433336
# 2014 - Oct          0.106211          1.315390                    -0.744029
# 2014 - Sep         -0.021664          1.152941                     0.825791
#
#             ...  Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  \
# Year-Month  ...
# 2014 - Apr  ...                                        0.094667    -0.502018
# 2014 - Aug  ...                                       -0.509428    -1.795012
# 2014 - Dec  ...                                       -0.679890     0.076196
# 2014 - Feb  ...                                        0.090181     0.404529
# 2014 - Jan  ...                                       -0.002227     0.487339
# 2014 - Jul  ...                                       -0.215156    -1.218249
# 2014 - Jun  ...                                       -0.004022    -0.372719
# 2014 - Mar  ...                                        0.176908     0.358040
# 2014 - May  ...                                        0.050108    -0.318966
# 2014 - Nov  ...                                       -0.702918    -0.669091
# 2014 - Oct  ...                                       -0.618883    -0.690883
# 2014 - Sep  ...                                       -0.527970    -0.211458
#
#             Average upland planted(million acres)  \
# Year-Month
# 2014 - Apr                              -0.256892
# 2014 - Aug                               0.315985
# 2014 - Dec                               0.099048
# 2014 - Feb                              -0.256892
# 2014 - Jan                              -0.256892
# 2014 - Jul                               0.315985
# 2014 - Jun                               0.171748
# 2014 - Mar                              -0.256892
# 2014 - May                              -0.256892
# 2014 - Nov                               0.099048
# 2014 - Oct                               0.099048
# 2014 - Sep                               0.099048
#
#             Average upland harvested(million acres)  yieldperharvested acre  \
# Year-Month
# 2014 - Apr                                -1.264152               -0.189068
# 2014 - Aug                                 1.105759                0.630632
# 2014 - Dec                                 0.765768               -1.242967
# 2014 - Feb                                -1.264152                0.591599
# 2014 - Jan                                -1.264152                0.591599
# 2014 - Jul                                -0.235064                0.474499
# 2014 - Jun                                -0.235064                0.747732
# 2014 - Mar                                -1.264152                0.591599
# 2014 - May                                -1.373532                0.396432
# 2014 - Nov                                 0.765768               -0.345201
# 2014 - Oct                                 0.765768               -0.618434
# 2014 - Sep                                 0.765768               -0.071968
#
#             Production (in  480-lb netweright in million bales)  \
# Year-Month
# 2014 - Apr                                          -1.192738
# 2014 - Aug                                           1.166689
# 2014 - Dec                                           0.365025
# 2014 - Feb                                          -1.034007
# 2014 - Jan                                          -1.034007
# 2014 - Jul                                           0.670469
# 2014 - Jun                                          -0.052081
# 2014 - Mar                                          -1.034007
# 2014 - May                                          -1.172208
# 2014 - Nov                                           0.602370
# 2014 - Oct                                           0.531266
# 2014 - Sep                                           0.672972
#
#             Mill use  (in  480-lb netweright in million bales)   Exports  \
# Year-Month
# 2014 - Apr                                           0.151781  -0.638569
# 2014 - Aug                                           1.390375  -0.535727
# 2014 - Dec                                           1.390375  -0.947094
# 2014 - Feb                                           0.151781  -0.770794
# 2014 - Jan                                           0.151781  -0.770794
# 2014 - Jul                                           1.390375  -0.788424
# 2014 - Jun                                           0.755199  -1.082258
# 2014 - Mar                                           0.151781  -0.653260
# 2014 - May                                           0.151781  -0.814869
# 2014 - Nov                                           1.390375  -0.947094
# 2014 - Oct                                           1.390375  -0.947094
# 2014 - Sep                                           1.390375  -0.947094
#
#             DayCategory_Event  DayCategory_Federal Holiday
# Year-Month
# 2014 - Apr           2.112886                    -1.153113
# 2014 - Aug          -0.929670                    -1.153113
# 2014 - Dec           2.112886                     0.104828
# 2014 - Feb           0.591608                     0.104828
# 2014 - Jan          -0.929670                     1.362770
# 2014 - Jul          -0.929670                     0.104828
# 2014 - Jun           0.591608                    -1.153113
# 2014 - Mar          -0.929670                    -1.153113
# 2014 - May           0.591608                     0.104828
# 2014 - Nov          -0.929670                     1.362770
# 2014 - Oct           0.591608                     0.104828
# 2014 - Sep          -0.929670                     0.104828
#
# [12 rows x 45 columns]

# %%
train_target = train_target.sort_index()

X_train, X_val, y_train, y_val = train_test_split(train_data, train_target, test_size=0.1, random_state=42)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(100, input_dim=45, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),

    keras.layers.Dense(50, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),

    keras.layers.Dense(3, activation=None),
])

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
 early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10, 
    restore_best_weights=True
)

# %%
history = model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        epochs=100,
        batch_size=2,
        callbacks=[early_stopping]
    )
    
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 27/27 [==============================] - 1s 11ms/step - loss: 3943334.5000 - val_loss: 3726830.7500
# Epoch 2/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3942724.2500 - val_loss: 3726423.0000
# Epoch 3/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3942073.7500 - val_loss: 3726011.0000
# Epoch 4/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3941581.7500 - val_loss: 3725539.2500
# Epoch 5/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3940783.0000 - val_loss: 3724881.0000
# Epoch 6/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3939758.2500 - val_loss: 3724352.0000
# Epoch 7/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3938478.2500 - val_loss: 3723605.0000
# Epoch 8/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3937579.5000 - val_loss: 3722690.0000
# Epoch 9/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3936022.7500 - val_loss: 3720925.7500
# Epoch 10/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3933964.5000 - val_loss: 3719594.7500
# Epoch 11/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3931494.2500 - val_loss: 3716073.2500
# Epoch 12/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3930242.7500 - val_loss: 3712213.0000
# Epoch 13/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3925201.0000 - val_loss: 3709455.0000
# Epoch 14/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3921834.2500 - val_loss: 3705582.7500
# Epoch 15/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3917561.2500 - val_loss: 3699487.2500
# Epoch 16/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3911633.2500 - val_loss: 3695027.7500
# Epoch 17/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3908734.7500 - val_loss: 3689343.0000
# Epoch 18/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3903305.7500 - val_loss: 3682122.7500
# Epoch 19/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3895829.7500 - val_loss: 3675950.0000
# Epoch 20/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3889066.2500 - val_loss: 3670564.7500
# Epoch 21/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3880819.5000 - val_loss: 3663674.7500
# Epoch 22/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3874744.2500 - val_loss: 3656828.2500
# Epoch 23/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3865690.0000 - val_loss: 3649933.7500
# Epoch 24/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3855743.7500 - val_loss: 3640655.2500
# Epoch 25/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3847276.2500 - val_loss: 3630532.7500
# Epoch 26/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3840383.5000 - val_loss: 3617084.0000
# Epoch 27/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3825936.0000 - val_loss: 3606574.0000
# Epoch 28/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3811953.7500 - val_loss: 3596838.2500
# Epoch 29/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3805145.7500 - val_loss: 3588230.0000
# Epoch 30/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3788206.7500 - val_loss: 3573365.2500
# Epoch 31/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3776615.7500 - val_loss: 3558698.7500
# Epoch 32/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3761545.0000 - val_loss: 3548124.7500
# Epoch 33/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3752537.2500 - val_loss: 3531490.0000
# Epoch 34/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3744931.7500 - val_loss: 3522720.7500
# Epoch 35/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3722536.2500 - val_loss: 3505427.2500
# Epoch 36/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3708065.2500 - val_loss: 3487600.2500
# Epoch 37/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3694690.0000 - val_loss: 3466952.0000
# Epoch 38/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3681450.7500 - val_loss: 3451358.7500
# Epoch 39/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3664228.5000 - val_loss: 3443162.0000
# Epoch 40/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3649914.2500 - val_loss: 3437995.2500
# Epoch 41/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3635247.5000 - val_loss: 3428420.0000
# Epoch 42/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3612438.2500 - val_loss: 3407168.7500
# Epoch 43/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3592107.0000 - val_loss: 3387878.7500
# Epoch 44/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3583354.0000 - val_loss: 3372619.2500
# Epoch 45/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3568702.7500 - val_loss: 3351710.2500
# Epoch 46/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3540534.2500 - val_loss: 3325866.0000
# Epoch 47/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3529119.7500 - val_loss: 3310894.7500
# Epoch 48/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3517684.7500 - val_loss: 3297227.2500
# Epoch 49/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3487735.0000 - val_loss: 3277869.2500
# Epoch 50/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3473800.5000 - val_loss: 3259802.7500
# Epoch 51/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3452405.2500 - val_loss: 3249322.0000
# Epoch 52/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3430123.2500 - val_loss: 3227026.7500
# Epoch 53/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3406297.7500 - val_loss: 3218527.2500
# Epoch 54/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3388096.5000 - val_loss: 3200492.0000
# Epoch 55/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3381169.0000 - val_loss: 3176404.2500
# Epoch 56/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3353420.5000 - val_loss: 3149628.7500
# Epoch 57/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3345337.0000 - val_loss: 3136557.0000
# Epoch 58/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3322382.2500 - val_loss: 3123314.7500
# Epoch 59/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3280865.0000 - val_loss: 3102356.2500
# Epoch 60/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3287977.0000 - val_loss: 3086300.2500
# Epoch 61/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3271434.2500 - val_loss: 3059262.7500
# Epoch 62/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3236627.2500 - val_loss: 3042028.2500
# Epoch 63/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3226627.2500 - val_loss: 3022799.0000
# Epoch 64/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3186137.2500 - val_loss: 3003382.2500
# Epoch 65/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3168913.0000 - val_loss: 2976363.2500
# Epoch 66/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3145139.0000 - val_loss: 2959707.2500
# Epoch 67/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3116636.7500 - val_loss: 2927188.2500
# Epoch 68/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3118348.7500 - val_loss: 2889084.7500
# Epoch 69/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3073333.0000 - val_loss: 2855758.0000
# Epoch 70/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3062759.5000 - val_loss: 2845924.2500
# Epoch 71/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3046700.7500 - val_loss: 2825244.7500
# Epoch 72/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3007743.5000 - val_loss: 2805181.0000
# Epoch 73/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2993543.0000 - val_loss: 2782733.7500
# Epoch 74/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2989721.0000 - val_loss: 2763487.7500
# Epoch 75/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2952823.5000 - val_loss: 2746004.0000
# Epoch 76/100
# 27/27 [==============================] - 0s 4ms/step - loss: 2917406.5000 - val_loss: 2735700.0000
# Epoch 77/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2903746.0000 - val_loss: 2720145.2500
# Epoch 78/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2908758.0000 - val_loss: 2688079.2500
# Epoch 79/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2877025.2500 - val_loss: 2672263.7500
# Epoch 80/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2859389.0000 - val_loss: 2661413.2500
# Epoch 81/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2814476.5000 - val_loss: 2646922.5000
# Epoch 82/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2788536.0000 - val_loss: 2637954.7500
# Epoch 83/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2759565.2500 - val_loss: 2611816.0000
# Epoch 84/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2745694.0000 - val_loss: 2591532.0000
# Epoch 85/100
# 27/27 [==============================] - 0s 4ms/step - loss: 2731582.2500 - val_loss: 2562454.2500
# Epoch 86/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2711150.7500 - val_loss: 2522850.2500
# Epoch 87/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2703217.2500 - val_loss: 2501337.2500
# Epoch 88/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2660146.2500 - val_loss: 2483319.2500
# Epoch 89/100
# 27/27 [==============================] - 0s 4ms/step - loss: 2627792.2500 - val_loss: 2463953.2500
# Epoch 90/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2619333.0000 - val_loss: 2447702.2500
# Epoch 91/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2580754.2500 - val_loss: 2427993.0000
# Epoch 92/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2570231.7500 - val_loss: 2423900.7500
# Epoch 93/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2562740.7500 - val_loss: 2398532.0000
# Epoch 94/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2513210.0000 - val_loss: 2373260.7500
# Epoch 95/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2511430.0000 - val_loss: 2348723.2500
# Epoch 96/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2500817.0000 - val_loss: 2332709.2500
# Epoch 97/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2462079.5000 - val_loss: 2311586.2500
# Epoch 98/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2429491.0000 - val_loss: 2281651.2500
# Epoch 99/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2426873.0000 - val_loss: 2264440.5000
# Epoch 100/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2388375.7500 - val_loss: 2238812.0000

# %%
predictions = model.predict(test_data)
# Out:
# 1/1 [==============================] - 0s 108ms/step

# %%
predictions
# Out:
# array([[1096.0288 ,  897.61725,  997.1758 ],
#        [ 889.213  ,  718.7239 ,  808.1289 ],
#        [ 973.65186,  797.22925,  883.89844],
#        [ 982.0126 ,  798.5262 ,  890.2977 ],
#        [ 725.74646,  597.9477 ,  658.4682 ],
#        [ 925.78296,  750.90216,  847.64   ],
#        [ 906.9441 ,  738.2777 ,  823.2376 ],
#        [ 762.20636,  628.62616,  685.9989 ],
#        [ 984.95654,  803.69794,  897.3303 ],
#        [ 958.65027,  784.1797 ,  874.51904],
#        [ 968.06665,  786.72974,  882.78796],
#        [ 892.5283 ,  724.2252 ,  810.75867]], dtype=float32)

# %%
def month_text_to_num(text):
    months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    return months.index(text) + 1
    
year = [date[:4] for date in test_data.index]
months = []
for i in [month_text_to_num(date[7:]) for date in test_data.index]:
    months.extend([i] * 3)
months
year = [2014 for i in range(len(months))]

# %%
sales = []
for i in predictions:
    for j in i:
        sales.append(j)
product_category = []
for i in range(int(len(sales)/3)):
    product_category.extend(['WomenClothing', 'MenClothing', 'OtherClothing'])

submission = pd.DataFrame({
    'Month': months,
    'ProductCategory': product_category,
    'Sales(In ThousandDollars)': sales
})
submission.sort_values(by=['Month', 'ProductCategory'], ascending=[True, False], inplace=True)
submission.reset_index(drop=True, inplace=True)
submission = submission.drop(columns=['Month', 'ProductCategory'])
submission.index = range(1, len(submission) + 1)
submission = submission.rename_axis('Year')
submission.to_csv('submission.csv')
